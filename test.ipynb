# %%
from importlib import reload

import TTN

reload(TTN)
# Out:
# <module 'TTN' from 'c:\\Users\\norma\\OneDrive\\Desktop\\PProjects\\Tic-Tac-Nope\\TTN.py'>

# %%
game = TTN.TTN()
game.define_empty_tokens([(0,0),(1,1),(2,0)])
print(game)
print(game.can_move(0,0,"X"))
print(game.can_move(0,0,"O"))
# Out:
# ■ |   | ■
# ---------
#   | ■ |
# ---------
#   |   |
# True
# None
